# %% [markdown]
# https://www.acmicpc.net/problem/1075

# %%
n = int(input())
f = int(input())
z = n%fm
print(z)
if z == 0:
  print('00')
elif z != 0:
  m = n-(n%100)
  print(m)
  n = (m+(m%f))%100
  if n == 0:
    print('00')
  else:
    print(n)

#range(23400,23500)
# Out:
# 32442
# 99
# 69
# 32400
# 27

# %%
n = int(input())
f = int(input())
m = n-(n%100)
p = m + 100
x = []
for i in range(m,p):
  if i%f == 0:
    x.append(i)
z = min(x)
z = z%100
if z <10:
  z = str(z)
  print('0'+z)
else:
  print(z)
# Out:
# 428392
# 17
# 15
